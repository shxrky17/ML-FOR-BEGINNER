# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import dbscan
from sklearn import metrics

# %%
X,y=datasets.make_circles(n_samples=500,factor=0.4,noise=0.03,random_state=42,shuffle=False)
X.shape,y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.figure(figsize=(10,7),facecolor='pink')
sc=plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='prism')

# %%
optics=OPTICS(max_eps=200,min_samples=24)
optics.fit(X)
labels=optics.labels_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 optics=OPTICS(max_eps=200,minPts=2,min_samples=24)
#       2 optics.fit(X)
#       3 labels=optics.labels_
#
# TypeError: OPTICS.__init__() got an unexpected keyword argument 'minPts'

# %%
np.unique(labels)
# Out:
# array([0, 1])

# %%
np.unique(y,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([250, 250], dtype=int64))

# %%
np.unique(labels,return_counts=True)
# Out:
# (array([0, 1]), array([250, 250], dtype=int64))

# %%
(y==labels).all()
# Out:
# True

# %%
metrics.accuracy_score(y,labels)
# Out:
# 1.0

# %%
plt.figure(figsize=(10,6),facecolor='pink')
sc=plt.scatter(X[:,0],X[:,1],c=labels,s=50,cmap='viridis')
